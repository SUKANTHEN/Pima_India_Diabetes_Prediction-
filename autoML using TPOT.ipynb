# %%
import numpy as np 
import pandas as pd 
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../input/pima-indians-diabetes/train.csv')
df.head(3)

# %%
print(df.size)
print(df.shape)

# %%
indep = data.iloc[:, 0:8].values
target = data.iloc[:, 8].values
print(indep)
print(target)

# %%
X_train, X_test, y_train, y_test = train_test_split(indep,target,train_size=0.75, test_size=0.25)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
tpot = TPOTClassifier(verbosity=2, max_time_mins=10)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))

# %%
tpot.fitted_pipeline_

# %%
print(tpot.score(X_test, y_test))

# %%
tpot.export('Diabetes_Prediction.py')
